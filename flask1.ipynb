# %%
#Q1. What is Flask Framework? What are the advantages of Flask Framework?
#Flask is a lightweight Python web framework with advantages like simplicity, flexibility, scalability, and a strong community.

# %%
#Q2. Create a simple Flask application to display ‘Hello World!!’.
from flask import Flask
app = Flask(__name__)

@app.route("/")
def hello_world():
    return "Hello World"

if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.18.0.3:5000
# Press CTRL+C to quit

# %% [markdown]
# ![Screenshot (386).png](attachment:b32918fd-6a7f-41fa-86b0-d93208221b15.png)

# %%
#Q3. What is App routing in Flask? Why do we use app routes?
'''
App routing in Flask refers to mapping URL patterns to specific view functions or methods in a Flask application. 
It allows us to create different endpoints or pages for our web application, enabling organized and user-friendly navigation.
'''

# %%
'''Q4 Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
route to show the following details:
Company Name: ABC Corporation
Location: India
Contact Detail: 999-999-9999'''

from flask import Flask

app = Flask(__name__)

@app.route("/")
def message():
    return"Company Name: ABC Corporation <br> Location: India <br> Contact Detail: 999-999-9999"

@app.route("/welcome")
def welcome():
    return "<h1>Welcome to ABC Corporation</h1>"

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot (387).png](attachment:1c36ba0e-8d98-4c3d-b60a-69ce1ba75a84.png)

# %% [markdown]
# ![Screenshot (388).png](attachment:76e8a1f9-fd17-4a64-8b1c-fd455c7ee1a8.png)

# %%
#Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.
